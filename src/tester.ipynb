# %% [markdown]
# # Flow Matching
# Scientific Machine Learning Seminar - SoSe 2026 - Universität Heidelberg
#
# Simon Tebeck

# %%
import numpy as np
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.get_device_name()
# Out:
# 'NVIDIA GeForce RTX 5050 Laptop GPU'
